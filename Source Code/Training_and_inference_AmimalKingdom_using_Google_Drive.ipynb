# %% [markdown]
# # Training and inference on your own data using Google Drive

# %% [markdown]
# In this notebook we'll install SLEAP, import training data into Colab using [Google Drive](https://www.google.com/drive), and run training and inference.

# %% [markdown]
# ## Install SLEAP
# Note: Before installing SLEAP check [SLEAP releases](https://github.com/talmolab/sleap/releases) page for the latest version.

# %%
# !pip uninstall -y opencv-python opencv-contrib-python
# !pip install sleap
# Out:
# Found existing installation: opencv-python 4.7.0.72
# Uninstalling opencv-python-4.7.0.72:
#   Successfully uninstalled opencv-python-4.7.0.72
# Found existing installation: opencv-contrib-python 4.7.0.72
# Uninstalling opencv-contrib-python-4.7.0.72:
#   Successfully uninstalled opencv-contrib-python-4.7.0.72
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sleap
#   Downloading sleap-1.3.1-py3-none-any.whl (64.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 MB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.23.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from sleap) (1.22.4)
# Collecting attrs<=21.4.0,>=21.2.0 (from sleap)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.1 MB/s eta 0:00:00
# Collecting cattrs==1.1.1 (from sleap)
#   Downloading cattrs-1.1.1-py3-none-any.whl (16 kB)
# Collecting jsonpickle==1.2 (from sleap)
#   Downloading jsonpickle-1.2-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from sleap) (3.1)
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.10/dist-packages (from sleap) (0.13.0)
# Collecting h5py<=3.7.0,>=3.1.0 (from sleap)
#   Downloading h5py-3.7.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 109.4 MB/s eta 0:00:00
# Collecting python-rapidjson (from sleap)
#   Downloading python_rapidjson-1.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 79.6 MB/s eta 0:00:00
# Collecting opencv-python<=4.6.0,>=4.2.0 (from sleap)
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from sleap) (1.5.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from sleap) (5.9.5)
# Collecting qtpy>=2.0.1 (from sleap)
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.10/dist-packages (from sleap) (23.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from sleap) (6.0)
# Requirement already satisfied: pillow<=8.4.0,>=8.3.1 in /usr/local/lib/python3.10/dist-packages (from sleap) (8.4.0)
# Collecting imageio<=2.15.0 (from sleap)
#   Downloading imageio-2.15.0-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 83.3 MB/s eta 0:00:00
# Requirement already satisfied: imgaug==0.4.0 in /usr/local/lib/python3.10/dist-packages (from sleap) (0.4.0)
# Collecting scipy<=1.9.0,>=1.4.1 (from sleap)
#   Downloading scipy-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from sleap) (0.19.3)
# Collecting scikit-learn==1.0.* (from sleap)
#   Downloading scikit_learn-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 52.8 MB/s eta 0:00:00
# Collecting scikit-video (from sleap)
#   Downloading scikit_video-1.1.11-py2.py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 98.5 MB/s eta 0:00:00
# Collecting imgstore==0.2.9 (from sleap)
#   Downloading imgstore-0.2.9-py2.py3-none-any.whl (904 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.1/904.1 kB 71.1 MB/s eta 0:00:00
# Collecting qimage2ndarray>=1.9.0 (from sleap)
#   Downloading qimage2ndarray-1.10.0-py3-none-any.whl (12 kB)
# Collecting jsmin (from sleap)
#   Downloading jsmin-3.0.1.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from sleap) (0.12.2)
# Collecting pykalman==0.9.5 (from sleap)
#   Downloading pykalman-0.9.5.tar.gz (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.9/228.9 kB 28.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting segmentation-models==1.0.1 (from sleap)
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting rich==10.16.1 (from sleap)
#   Downloading rich-10.16.1-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 28.9 MB/s eta 0:00:00
# Collecting certifi<=2021.10.8,>=2017.4.17 (from sleap)
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.2/149.2 kB 10.9 MB/s eta 0:00:00
# Collecting pynwb (from sleap)
#   Downloading pynwb-2.3.2-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.9/131.9 kB 18.2 MB/s eta 0:00:00
# Collecting ndx-pose (from sleap)
#   Downloading ndx_pose-0.1.1-py2.py3-none-any.whl (8.3 kB)
# Collecting nixio>=1.5.3 (from sleap)
#   Downloading nixio-1.5.3-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 14.2 MB/s eta 0:00:00
# Collecting tensorflow<2.9.0,>=2.6.3 (from sleap)
#   Downloading tensorflow-2.8.4-cp310-cp310-manylinux2010_x86_64.whl (498.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 3.3 MB/s eta 0:00:00
# Collecting PySide2<=5.14.1,>=5.13.2 (from sleap)
#   Downloading PySide2-5.13.2-5.13.2-cp35.cp36.cp37-abi3-manylinux1_x86_64.whl (156.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.1/156.1 MB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->sleap) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->sleap) (3.7.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug==0.4.0->sleap) (2.0.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from imgstore==0.2.9->sleap) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from imgstore==0.2.9->sleap) (2022.7.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from imgstore==0.2.9->sleap) (4.3)
# Collecting colorama<0.5.0,>=0.4.0 (from rich==10.16.1->sleap)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting commonmark<0.10.0,>=0.9.0 (from rich==10.16.1->sleap)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from rich==10.16.1->sleap) (2.14.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0.*->sleap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0.*->sleap) (3.1.0)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models==1.0.1->sleap)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.5 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models==1.0.1->sleap)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models==1.0.1->sleap)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Collecting shiboken2==5.13.2 (from PySide2<=5.14.1,>=5.13.2->sleap)
#   Downloading shiboken2-5.13.2-5.13.2-cp35.cp36.cp37-abi3-manylinux1_x86_64.whl (832 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.9/832.9 kB 73.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from qtpy>=2.0.1->sleap) (23.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->sleap) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->sleap) (1.4.1)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (23.3.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (0.2.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow<2.9.0,>=2.6.3->sleap)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (3.3.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow<2.9.0,>=2.6.3->sleap)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 79.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow<2.9.0,>=2.6.3->sleap)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 98.6 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.9,>=2.8 (from tensorflow<2.9.0,>=2.6.3->sleap)
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 50.6 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow<2.9.0,>=2.6.3->sleap)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 64.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.6.3->sleap) (1.54.0)
# Collecting hdmf<4,>=2.5.6 (from ndx-pose->sleap)
#   Downloading hdmf-3.6.1-py3-none-any.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.1/197.1 kB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.9.0,>=2.6.3->sleap) (0.40.0)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from hdmf<4,>=2.5.6->ndx-pose->sleap) (4.3.3)
# Collecting ruamel.yaml>=0.16 (from hdmf<4,>=2.5.6->ndx-pose->sleap)
#   Downloading ruamel.yaml-0.17.31-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.1/112.1 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->sleap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->sleap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->sleap) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->sleap) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug==0.4.0->sleap) (3.0.9)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (2.27.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 130.3 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (2.3.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal->imgstore==0.2.9->sleap) (0.1.0.post0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (1.3.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf<4,>=2.5.6->ndx-pose->sleap) (0.19.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (3.4)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.16->hdmf<4,>=2.5.6->ndx-pose->sleap)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 49.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (2.1.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal->imgstore==0.2.9->sleap) (2023.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.6.3->sleap) (3.2.2)
# Building wheels for collected packages: pykalman, jsmin
#   Building wheel for pykalman (setup.py) ... done
#   Created wheel for pykalman: filename=pykalman-0.9.5-py3-none-any.whl size=48442 sha256=7c4a863ee1ea2b7521f6b8c3006747c1fd97b3ad1b4c7b20450e447a6d7c3c49
#   Stored in directory: /root/.cache/pip/wheels/76/33/ef/5f332226e13a5089c6dd4b01cc2bcb59491d18f955fa2d3807
#   Building wheel for jsmin (setup.py) ... done
#   Created wheel for jsmin: filename=jsmin-3.0.1-py3-none-any.whl size=13765 sha256=567bac7754fadc654d79f59b1ec8bb6ab9b11fc5c74b7bcb2470645488b7b48a
#   Stored in directory: /root/.cache/pip/wheels/9a/eb/65/4a07a200d454fb40cbd51a2deee3c5d26285321e3bbbe627a5
# Successfully built pykalman jsmin
# Installing collected packages: tensorflow-estimator, shiboken2, pykalman, keras, jsonpickle, jsmin, commonmark, certifi, tensorboard-data-server, scipy, ruamel.yaml.clib, qtpy, qimage2ndarray, python-rapidjson, PySide2, protobuf, opencv-python, keras-preprocessing, imageio, h5py, colorama, attrs, scikit-video, scikit-learn, ruamel.yaml, rich, nixio, keras-applications, cattrs, imgstore, image-classifiers, hdmf, google-auth-oauthlib, efficientnet, tensorboard, segmentation-models, pynwb, tensorflow, ndx-pose, sleap
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: jsonpickle
#     Found existing installation: jsonpickle 3.0.1
#     Uninstalling jsonpickle-3.0.1:
#       Successfully uninstalled jsonpickle-3.0.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.12.7
#     Uninstalling certifi-2022.12.7:
#       Successfully uninstalled certifi-2022.12.7
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1

# %% [markdown]
# ## Import training data into Colab with Google Drive
# We'll first prepare and export the training data from SLEAP, then upload it to Google Drive, and then mount Google Drive  into this Colab notebook.

# %% [markdown]
# ### Create and export the training job package
# A self-contained **training job package** contains a .slp file with labeled data and images which will be used for training, as well as .json training configuration file(s).
#
# A training job package can be exported in the SLEAP GUI fron the "Run Training.." dialog under the "Predict" menu.

# %% [markdown]
# ### Upload training job package to Google Drive
# To be consistent with the examples in this notebook, name the SLEAP project `colab` and create a directory called `sleap` in the root of your Google Drive. Then upload the exported training job package `colab.slp.training_job.zip` into `sleap` directory.
#
# If you place your training pckage somewhere else, or name it differently, adjust the paths/filenames/parameters below accordingly.

# %% [markdown]
# ### Mount your Google Drive
# Mounting your Google Drive will allow you to accessed the uploaded training job package in this notebook. When prompted to log into your Google account, give Colab access and the copy the authorization code into a field below (+ hit 'return').

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %% [markdown]
# Let's set your current working directory to the directory with your training job package and unpack it there. Later on the output from training (i.e., the models) and from interence (i.e., predictions) will all be saved in this directory as well.

# %%
import os
os.chdir("/content/drive/MyDrive/COCOHorseSleapPose")
# !unzip /content/drive/MyDrive/COCOHorseSleapPose/HorseCOCO.slp.training_job.zip
# !ls
# Out:
# Archive:  /content/drive/MyDrive/COCOHorseSleapPose/HorseCOCO.slp.training_job.zip
#   inflating: centered_instance.json
#   inflating: centroid.json
#   inflating: HorseCOCO.pkg.slp
#   inflating: inference-script.sh
#   inflating: jobs.yaml
#   inflating: train-script.sh
# centered_instance.json	HorseCOCO.slp.training_job.zip	train-script.sh
# centroid.json		inference-script.sh
# HorseCOCO.pkg.slp	jobs.yaml

# %% [markdown]
# ## Train a model
#
# Let's train a model with the training profile (.json file) and the project data (.slp file) you have exported from SLEAP.
#
#
# ### Note on training profiles
# Depending on the pipeline you chose in the training dialog, the config filename(s) will be:
#
# - for a **bottom-up** pipeline approach: `multi_instance.json` (this is the pipeline we assume here),
#
# - for a **top-down** pipeline, you'll have a different profile for each of the models: `centroid.json` and `centered_instance.json`,
#
# - for a **single animal** pipeline: `single_instance.json`.
#
#
# ### Note on training process
# When you start training, you'll first see the training parameters and then the training and validation loss for each training epoch.
#
# As soon as you're satisfied with the validation loss you see for an epoch during training, you're welcome to stop training by clicking the stop button. The version of the model with the lowest validation loss is saved during training, and that's what will be used for inference.
#
# If you don't stop training, it will run for 200 epochs or until validation loss fails to improve for some number of epochs (controlled by the early_stopping fields in the training profile).

# %%
# !sleap-train multi_instance.json colab.pkg.slp

# %% [markdown]
# ## Train Top_down Model

# %%
# !sleap-train /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/centroid.json /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/HorseCOCO.pkg.slp
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:sleap.nn.training:Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
# INFO:sleap.nn.training:Training labels file: /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/HorseCOCO.pkg.slp
# INFO:sleap.nn.training:Training profile: /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/centroid.json
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Arguments:
# INFO:sleap.nn.training:{
#     "training_job_path": "/content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/centroid.json",
#     "labels_path": "/content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/HorseCOCO.pkg.slp",
#     "video_paths": [
#         ""
#     ],
#     "val_labels": null,
#     "test_labels": null,
#     "base_checkpoint": null,
#     "tensorboard": false,
#     "save_viz": false,
#     "zmq": false,
#     "run_name": "",
#     "prefix": "",
#     "suffix": "",
#     "cpu": false,
#     "first_gpu": false,
#     "last_gpu": false,
#     "gpu": "auto"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Training job:
# INFO:sleap.nn.training:{
#     "data": {
#         "labels": {
#             "training_labels": null,
#             "validation_labels": null,
#             "validation_fraction": 0.1,
#             "test_labels": null,
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 0.5,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 16,
#                 "output_stride": 2,
#                 "filters": 16,
#                 "filters_rate": 2.0,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": {
#                 "anchor_part": null,
#                 "sigma": 2.5,
#                 "output_stride": 2,
#                 "loss_weight": 1.0,
#                 "offset_refinement": false
#             },
#             "centered_instance": null,
#             "multi_instance": null,
#             "multi_class_bottomup": null,
#             "multi_class_topdown": null
#         },
#         "base_checkpoint": null
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -15.0,
#             "rotation_max_angle": 15.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.9,
#             "scale_max": 1.1,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-08,
#             "plateau_patience": 20
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": "230513_124413",
#         "run_name_prefix": "",
#         "run_name_suffix": ".centroid",
#         "runs_folder": "models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": true,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "1.2.8",
#     "filename": "/content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/centroid.json"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Auto-selected GPU 0 with 15098 MiB of free memory.
# INFO:sleap.nn.training:Using GPU 0 for acceleration.
# INFO:sleap.nn.training:Disabled GPU memory pre-allocation.
# INFO:sleap.nn.training:System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Initializing trainer...
# INFO:sleap.nn.training:Loading training labels from: /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/HorseCOCO.pkg.slp
# INFO:sleap.nn.training:Creating training and validation splits from validation fraction: 0.1
# INFO:sleap.nn.training:  Splits: Training = 992 / Validation = 110.
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# INFO:sleap.nn.training:Loaded test example. [7.696s]
# INFO:sleap.nn.training:  Input shape: (192, 320, 3)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=16, filters_rate=2.0, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=4, middle_block=True, up_blocks=3, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 16
# INFO:sleap.nn.training:  Parameters: 1,953,393
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = CentroidConfmapsHead(anchor_part=None, sigma=2.5, output_stride=2, loss_weight=1.0)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 96, 160, 1), dtype=tf.float32, name=None), name='CentroidConfmapsHead/BiasAdd:0', description="created by layer 'CentroidConfmapsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 992
# INFO:sleap.nn.training:Validation set: n = 110
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-08, plateau_patience=20)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: models/230513_124413.centroid
# INFO:sleap.nn.training:Setting up visualization...
# 2023-05-13 10:16:15.212252: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -34 } dim { size: -35 } dim { size: -36 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -37 } dim { size: -38 } dim { size: 1 } } }
# 2023-05-13 10:16:16.710095: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -34 } dim { size: -35 } dim { size: -36 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -37 } dim { size: -38 } dim { size: 1 } } }
# Unable to use Qt backend for matplotlib. This probably means Qt is running headless.
# Unable to use Qt backend for matplotlib. This probably means Qt is running headless.
# INFO:sleap.nn.training:Finished trainer set up. [13.4s]
# INFO:sleap.nn.training:Creating tf.data.Datasets for training data generation...
ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 248/248 - 19s - loss: 1.8853e-04 - val_loss: 4.7963e-04 - lr: 7.8125e-07 - 19s/epoch - 75ms/step
# Epoch 105/200
# 248/248 - 19s - loss: 1.8834e-04 - val_loss: 4.7203e-04 - lr: 3.9062e-07 - 19s/epoch - 77ms/step
# Epoch 106/200
# 248/248 - 19s - loss: 1.8904e-04 - val_loss: 4.6702e-04 - lr: 3.9062e-07 - 19s/epoch - 77ms/step
# Epoch 107/200
# 248/248 - 19s - loss: 1.9178e-04 - val_loss: 4.7002e-04 - lr: 3.9062e-07 - 19s/epoch - 77ms/step
# Epoch 108/200
# 248/248 - 20s - loss: 1.8962e-04 - val_loss: 4.9208e-04 - lr: 3.9062e-07 - 20s/epoch - 79ms/step
# Epoch 109/200
# 248/248 - 20s - loss: 1.8476e-04 - val_loss: 4.9190e-04 - lr: 3.9062e-07 - 20s/epoch - 79ms/step
# Epoch 110/200
# 248/248 - 19s - loss: 1.8767e-04 - val_loss: 4.7203e-04 - lr: 3.9062e-07 - 19s/epoch - 76ms/step
# Epoch 111/200
#
# Epoch 111: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# 248/248 - 20s - loss: 1.8376e-04 - val_loss: 5.1936e-04 - lr: 3.9062e-07 - 20s/epoch - 79ms/step
# Epoch 112/200
# 248/248 - 19s - loss: 1.8357e-04 - val_loss: 4.8980e-04 - lr: 1.9531e-07 - 19s/epoch - 77ms/step
# Epoch 113/200
# 248/248 - 19s - loss: 1.8757e-04 - val_loss: 4.7679e-04 - lr: 1.9531e-07 - 19s/epoch - 78ms/step
# Epoch 114/200
# 248/248 - 19s - loss: 1.8525e-04 - val_loss: 4.5951e-04 - lr: 1.9531e-07 - 19s/epoch - 78ms/step
# Epoch 114: early stopping
# INFO:sleap.nn.training:Finished training loop. [37.1 min]
# INFO:sleap.nn.training:Deleting visualization directory: models/230513_124413.centroid/viz
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-13 10:53:46.168833: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -69 } dim { size: -70 } dim { size: -71 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -5 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: -72 } dim { size: -73 } dim { size: 1 } } }
# 2023-05-13 10:53:46.169329: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -5 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: -81 } dim { size: -82 } dim { size: 3 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 67.4 FPS
# /usr/local/lib/python3.10/dist-packages/sleap/nn/evals.py:506: RuntimeWarning: Mean of empty slice
#   "dist.avg": np.nanmean(dists),
# /usr/local/lib/python3.10/dist-packages/sleap/nn/evals.py:539: RuntimeWarning: Mean of empty slice.
#   mPCK = mPCK_parts.mean()
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/sleap/nn/evals.py:633: RuntimeWarning: Mean of empty slice.
#   pair_pck = metrics["pck.pcks"].mean(axis=-1).mean(axis=-1)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /usr/local/lib/python3.10/dist-packages/sleap/nn/evals.py:635: RuntimeWarning: Mean of empty slice.
#   metrics["oks.mOKS"] = pair_oks.mean()
# WARNING:sleap.nn.evals:Failed to compute metrics.
# INFO:sleap.nn.evals:Saved predictions: models/230513_124413.centroid/labels_pr.train.slp
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-13 10:54:09.070382: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -69 } dim { size: -70 } dim { size: -71 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -5 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: -72 } dim { size: -73 } dim { size: 1 } } }
# 2023-05-13 10:54:09.071069: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -5 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: -81 } dim { size: -82 } dim { size: 3 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺  98% ETA: 0:00:01 44.0 FPS2023-05-13 10:54:14.236534: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -69 } dim { size: -70 } dim { size: -71 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -5 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: -72 } dim { size: -73 } dim { size: 1 } } }
# 2023-05-13 10:54:14.237207: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 2 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -5 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -5 } dim { size: -81 } dim { size: -82 } dim { size: 3 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 14.9 FPS
# /usr/local/lib/python3.10/dist-packages/sleap/nn/evals.py:506: RuntimeWarning: Mean of empty slice
#   "dist.avg": np.nanmean(dists),
# /usr/local/lib/python3.10/dist-packages/sleap/nn/evals.py:539: RuntimeWarning: Mean of empty slice.
#   mPCK = mPCK_parts.mean()
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/sleap/nn/evals.py:633: RuntimeWarning: Mean of empty slice.
#   pair_pck = metrics["pck.pcks"].mean(axis=-1).mean(axis=-1)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /usr/local/lib/python3.10/dist-packages/sleap/nn/evals.py:635: RuntimeWarning: Mean of empty slice.
#   metrics["oks.mOKS"] = pair_oks.mean()
# WARNING:sleap.nn.evals:Failed to compute metrics.
# INFO:sleap.nn.evals:Saved predictions: models/230513_124413.centroid/labels_pr.val.slp

# %%
# !sleap-train /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/centered_instance.json /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/HorseCOCO.pkg.slp
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:sleap.nn.training:Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
# INFO:sleap.nn.training:Training labels file: /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/HorseCOCO.pkg.slp
# INFO:sleap.nn.training:Training profile: /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/centered_instance.json
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Arguments:
# INFO:sleap.nn.training:{
#     "training_job_path": "/content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/centered_instance.json",
#     "labels_path": "/content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/HorseCOCO.pkg.slp",
#     "video_paths": [
#         ""
#     ],
#     "val_labels": null,
#     "test_labels": null,
#     "base_checkpoint": null,
#     "tensorboard": false,
#     "save_viz": false,
#     "zmq": false,
#     "run_name": "",
#     "prefix": "",
#     "suffix": "",
#     "cpu": false,
#     "first_gpu": false,
#     "last_gpu": false,
#     "gpu": "auto"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Training job:
# INFO:sleap.nn.training:{
#     "data": {
#         "labels": {
#             "training_labels": null,
#             "validation_labels": null,
#             "validation_fraction": 0.1,
#             "test_labels": null,
#             "split_by_inds": false,
#             "training_inds": null,
#             "validation_inds": null,
#             "test_inds": null,
#             "search_path_hints": [],
#             "skeletons": []
#         },
#         "preprocessing": {
#             "ensure_rgb": false,
#             "ensure_grayscale": false,
#             "imagenet_mode": null,
#             "input_scaling": 1.0,
#             "pad_to_stride": null,
#             "resize_and_pad_to_target": true,
#             "target_height": null,
#             "target_width": null
#         },
#         "instance_cropping": {
#             "center_on_part": null,
#             "crop_size": null,
#             "crop_size_detection_padding": 16
#         }
#     },
#     "model": {
#         "backbone": {
#             "leap": null,
#             "unet": {
#                 "stem_stride": null,
#                 "max_stride": 16,
#                 "output_stride": 4,
#                 "filters": 24,
#                 "filters_rate": 2.0,
#                 "middle_block": true,
#                 "up_interpolate": true,
#                 "stacks": 1
#             },
#             "hourglass": null,
#             "resnet": null,
#             "pretrained_encoder": null
#         },
#         "heads": {
#             "single_instance": null,
#             "centroid": null,
#             "centered_instance": {
#                 "anchor_part": null,
#                 "part_names": null,
#                 "sigma": 2.5,
#                 "output_stride": 4,
#                 "loss_weight": 1.0,
#                 "offset_refinement": false
#             },
#             "multi_instance": null,
#             "multi_class_bottomup": null,
#             "multi_class_topdown": null
#         },
#         "base_checkpoint": null
#     },
#     "optimization": {
#         "preload_data": true,
#         "augmentation_config": {
#             "rotate": true,
#             "rotation_min_angle": -15.0,
#             "rotation_max_angle": 15.0,
#             "translate": false,
#             "translate_min": -5,
#             "translate_max": 5,
#             "scale": false,
#             "scale_min": 0.9,
#             "scale_max": 1.1,
#             "uniform_noise": false,
#             "uniform_noise_min_val": 0.0,
#             "uniform_noise_max_val": 10.0,
#             "gaussian_noise": false,
#             "gaussian_noise_mean": 5.0,
#             "gaussian_noise_stddev": 1.0,
#             "contrast": false,
#             "contrast_min_gamma": 0.5,
#             "contrast_max_gamma": 2.0,
#             "brightness": false,
#             "brightness_min_val": 0.0,
#             "brightness_max_val": 10.0,
#             "random_crop": false,
#             "random_crop_height": 256,
#             "random_crop_width": 256,
#             "random_flip": false,
#             "flip_horizontal": true
#         },
#         "online_shuffling": true,
#         "shuffle_buffer_size": 128,
#         "prefetch": true,
#         "batch_size": 4,
#         "batches_per_epoch": null,
#         "min_batches_per_epoch": 200,
#         "val_batches_per_epoch": null,
#         "min_val_batches_per_epoch": 10,
#         "epochs": 200,
#         "optimizer": "adam",
#         "initial_learning_rate": 0.0001,
#         "learning_rate_schedule": {
#             "reduce_on_plateau": true,
#             "reduction_factor": 0.5,
#             "plateau_min_delta": 1e-06,
#             "plateau_patience": 5,
#             "plateau_cooldown": 3,
#             "min_learning_rate": 1e-08
#         },
#         "hard_keypoint_mining": {
#             "online_mining": false,
#             "hard_to_easy_ratio": 2.0,
#             "min_hard_keypoints": 2,
#             "max_hard_keypoints": null,
#             "loss_scale": 5.0
#         },
#         "early_stopping": {
#             "stop_training_on_plateau": true,
#             "plateau_min_delta": 1e-08,
#             "plateau_patience": 10
#         }
#     },
#     "outputs": {
#         "save_outputs": true,
#         "run_name": "230513_124413",
#         "run_name_prefix": "",
#         "run_name_suffix": ".centered_instance",
#         "runs_folder": "models",
#         "tags": [
#             ""
#         ],
#         "save_visualizations": true,
#         "delete_viz_images": true,
#         "zip_outputs": false,
#         "log_to_csv": true,
#         "checkpointing": {
#             "initial_model": false,
#             "best_model": true,
#             "every_epoch": false,
#             "latest_model": false,
#             "final_model": false
#         },
#         "tensorboard": {
#             "write_logs": false,
#             "loss_frequency": "epoch",
#             "architecture_graph": false,
#             "profile_graph": false,
#             "visualizations": true
#         },
#         "zmq": {
#             "subscribe_to_controller": false,
#             "controller_address": "tcp://127.0.0.1:9000",
#             "controller_polling_timeout": 10,
#             "publish_updates": false,
#             "publish_address": "tcp://127.0.0.1:9001"
#         }
#     },
#     "name": "",
#     "description": "",
#     "sleap_version": "1.2.8",
#     "filename": "/content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/centered_instance.json"
# }
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Auto-selected GPU 0 with 15098 MiB of free memory.
# INFO:sleap.nn.training:Using GPU 0 for acceleration.
# INFO:sleap.nn.training:Disabled GPU memory pre-allocation.
# INFO:sleap.nn.training:System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
# INFO:sleap.nn.training:
# INFO:sleap.nn.training:Initializing trainer...
# INFO:sleap.nn.training:Loading training labels from: /content/drive/MyDrive/COCOHorseSleapPose/TrainJopPgk/HorseCOCO.pkg.slp
# INFO:sleap.nn.training:Creating training and validation splits from validation fraction: 0.1
# INFO:sleap.nn.training:  Splits: Training = 992 / Validation = 110.
# INFO:sleap.nn.training:Setting up for training...
# INFO:sleap.nn.training:Setting up pipeline builders...
# INFO:sleap.nn.training:Setting up model...
# INFO:sleap.nn.training:Building test pipeline...
# 2023-05-13 10:54:43.279196: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 624 } dim { size: 624 } dim { size: 3 } } }
# INFO:sleap.nn.training:Loaded test example. [6.958s]
# INFO:sleap.nn.training:  Input shape: (624, 624, 3)
# INFO:sleap.nn.training:Created Keras model.
# INFO:sleap.nn.training:  Backbone: UNet(stacks=1, filters=24, filters_rate=2.0, kernel_size=3, stem_kernel_size=7, convs_per_block=2, stem_blocks=0, down_blocks=4, middle_block=True, up_blocks=2, up_interpolate=True, block_contraction=False)
# INFO:sleap.nn.training:  Max stride: 16
# INFO:sleap.nn.training:  Parameters: 4,312,847
# INFO:sleap.nn.training:  Heads:
# INFO:sleap.nn.training:    [0] = CenteredInstanceConfmapsHead(part_names=['Head_Mid_Top', 'Eye_Left', 'Eye_Right', 'Mouth_Front_Top', 'Mouth_Back_Left', 'Mouth_Back_Right', 'Mouth_Front_Bottom', 'Shoulder_Left', 'Shoulder_Right', 'Elbow_Left', 'Elbow_Right', 'Wrist_Left', 'Wrist_Right', 'Torso_Mid_Back', 'Hip_Left', 'Hip_Right', 'Knee_Left', 'Knee_Right', 'Ankle_Left ', 'Ankle_Right', 'Tail_Top_Back', 'Tail_Mid_Back', 'Tail_End_Back'], anchor_part=None, sigma=2.5, output_stride=4, loss_weight=1.0)
# INFO:sleap.nn.training:  Outputs:
# INFO:sleap.nn.training:    [0] = KerasTensor(type_spec=TensorSpec(shape=(None, 156, 156, 23), dtype=tf.float32, name=None), name='CenteredInstanceConfmapsHead/BiasAdd:0', description="created by layer 'CenteredInstanceConfmapsHead'")
# INFO:sleap.nn.training:Training from scratch
# INFO:sleap.nn.training:Setting up data pipelines...
# INFO:sleap.nn.training:Training set: n = 992
# INFO:sleap.nn.training:Validation set: n = 110
# INFO:sleap.nn.training:Setting up optimization...
# INFO:sleap.nn.training:  Learning rate schedule: LearningRateScheduleConfig(reduce_on_plateau=True, reduction_factor=0.5, plateau_min_delta=1e-06, plateau_patience=5, plateau_cooldown=3, min_learning_rate=1e-08)
# INFO:sleap.nn.training:  Early stopping: EarlyStoppingConfig(stop_training_on_plateau=True, plateau_min_delta=1e-08, plateau_patience=10)
# INFO:sleap.nn.training:Setting up outputs...
# INFO:sleap.nn.training:Created run path: models/230513_124413.centered_instance
# INFO:sleap.nn.training:Setting up visualization...
# 2023-05-13 10:54:45.845713: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 624 } dim { size: 624 } dim { size: 3 } } }
# 2023-05-13 10:54:48.100396: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 624 } dim { size: 624 } dim { size: 3 } } }
W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 624 } dim { size: 624 } dim { size: 3 } } }
# 248/248 - 73s - loss: 5.4586e-05 - Head_Mid_Top: 8.2873e-05 - Eye_Left: 4.1694e-05 - Eye_Right: 5.2864e-05 - Mouth_Front_Top: 6.8752e-05 - Mouth_Back_Left: 5.2407e-05 - Mouth_Back_Right: 4.1623e-05 - Mouth_Front_Bottom: 4.7086e-05 - Shoulder_Left: 5.7004e-05 - Shoulder_Right: 5.7494e-05 - Elbow_Left: 6.2556e-05 - Elbow_Right: 6.8646e-05 - Wrist_Left: 4.5725e-05 - Wrist_Right: 4.4114e-05 - Torso_Mid_Back: 7.0069e-05 - Hip_Left: 4.6505e-05 - Hip_Right: 5.0418e-05 - Knee_Left: 5.5152e-05 - Knee_Right: 6.0289e-05 - Ankle_Left_: 4.2933e-05 - Ankle_Right: 4.2592e-05 - Tail_Top_Back: 3.4183e-05 - Tail_Mid_Back: 5.7439e-05 - Tail_End_Back: 7.3069e-05 - val_loss: 1.6957e-04 - val_Head_Mid_Top: 2.8042e-04 - val_Eye_Left: 1.1339e-04 - val_Eye_Right: 1.3334e-04 - val_Mouth_Front_Top: 2.7054e-04 - val_Mouth_Back_Left: 1.1553e-04 - val_Mouth_Back_Right: 8.5391e-05 - val_Mouth_Front_Bottom: 2.5781e-04 - val_Shoulder_Left: 2.2253e-04 - val_Shoulder_Right: 2.2817e-04 - val_Elbow_Left: 2.0668e-04 - val_Elbow_Right: 1.6427e-04 - val_Wrist_Left: 1.2455e-04 - val_Wrist_Right: 9.7574e-05 - val_Torso_Mid_Back: 2.3540e-04 - val_Hip_Left: 1.8289e-04 - val_Hip_Right: 1.5467e-04 - val_Knee_Left: 2.1687e-04 - val_Knee_Right: 1.7230e-04 - val_Ankle_Left_: 1.0593e-04 - val_Ankle_Right: 1.0236e-04 - val_Tail_Top_Back: 1.1217e-04 - val_Tail_Mid_Back: 1.6065e-04 - val_Tail_End_Back: 1.5659e-04 - lr: 2.5000e-05 - 73s/epoch - 293ms/step
# Epoch 85: early stopping
# INFO:sleap.nn.training:Finished training loop. [108.4 min]
# INFO:sleap.nn.training:Deleting visualization directory: models/230513_124413.centered_instance/viz
# INFO:sleap.nn.training:Saving evaluation metrics to model folder...
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-13 12:43:33.057184: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -26 } dim { size: -27 } dim { size: 3 } } }
# 2023-05-13 12:43:33.073204: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -52 } dim { size: -53 } dim { size: -54 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -9 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -9 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -9 } dim { size: -56 } dim { size: -57 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 25.6 FPS
# INFO:sleap.nn.evals:Saved predictions: models/230513_124413.centered_instance/labels_pr.train.slp
# INFO:sleap.nn.evals:Saved metrics: models/230513_124413.centered_instance/metrics.train.npz
# INFO:sleap.nn.evals:OKS mAP: 0.705180
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-13 12:44:17.155873: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -26 } dim { size: -27 } dim { size: 3 } } }
# 2023-05-13 12:44:17.164448: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -52 } dim { size: -53 } dim { size: -54 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -9 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -9 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -9 } dim { size: -56 } dim { size: -57 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺  98% ETA: 0:00:01 30.0 FPS2023-05-13 12:44:22.178220: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 2 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2000 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 40370176 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -26 } dim { size: -27 } dim { size: 3 } } }
# 2023-05-13 12:44:22.191694: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -52 } dim { size: -53 } dim { size: -54 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -9 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -9 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -9 } dim { size: -56 } dim { size: -57 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 10.1 FPS
# INFO:sleap.nn.evals:Saved predictions: models/230513_124413.centered_instance/labels_pr.val.slp
# INFO:sleap.nn.evals:Saved metrics: models/230513_124413.centered_instance/metrics.val.npz
# INFO:sleap.nn.evals:OKS mAP: 0.260104

# %% [markdown]
# If instead of bottom-up you've chosen the top-down pipeline (with two training configs), you would need to invoke two separate training jobs in sequence:
#
# - `!sleap-train centroid.json colab.pkg.slp`
# - `!sleap-train centered_instance.json colab.pkg.slp`

# %% [markdown]
# ## Predicting and tracking instances in uploaded video

# %% [markdown]
# ### Inference with top-down models using single video
#
# If you trained the pair of models needed for top-down inference, you can call `sleap-track` with `-m path/to/model` for each model, like so:

# %%
# !sleap-track /content/3.mp4 \
    --frames 0-5 \
    --tracking.tracker simple \
    -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance \
    -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-15 09:51:29.640459
# Args:
# {
# │   'data_path': '/content/3.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-5',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/3.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-15 09:51:39.444656: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-15 09:51:39.445274: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-15 09:51:39.450336: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━  67% ETA: -:--:-- ?2023-05-15 09:51:50.101342: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-15 09:51:50.102127: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 2 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-15 09:51:50.110306: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 0.6 FPS
# Finished inference at: 2023-05-15 09:51:56.659688
# Total runtime: 27.01924467086792 secs
# Predicted frames: 6/6
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/3.mp4 --frames 0-5 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/3.mp4',
# │   'output_path': '/content/3.mp4.predictions.slp',
# │   'total_elapsed': 27.01924467086792,
# │   'start_timestamp': '2023-05-15 09:51:29.640459',
# │   'finish_timestamp': '2023-05-15 09:51:56.659688'
# }
#
# Saved output: /content/3.mp4.predictions.slp

# %% [markdown]
# ### Inference with top-down models using Multiple video

# %%
import os
os.chdir("/content/drive/MyDrive/COCOHorseSleapPose")
# !unzip /content/drive/MyDrive/COCOHorseSleapPose/Videos.zip
# !ls
# Out:
# Archive:  /content/drive/MyDrive/COCOHorseSleapPose/Videos.zip
#   inflating: Videos/AHTCDBME.mp4
#   inflating: Videos/AKPNRXGD.mp4
#   inflating: Videos/AKXVOXGD.mp4
#   inflating: Videos/AMVQFXGD.mp4
#   inflating: Videos/AMZSRXGD.mp4
#   inflating: Videos/ANGLMXGD.mp4
#   inflating: Videos/ANMSEBME.mp4
#   inflating: Videos/APZQNXGD.mp4
#   inflating: Videos/AQCYDXGD.mp4
#   inflating: Videos/ARNCVXGD.mp4
#   inflating: Videos/ASHUOMHZ.mp4
#   inflating: Videos/ATSFLXGD.mp4
#   inflating: Videos/BERFBXGD.mp4
#   inflating: Videos/BOEFDXGD.mp4
#   inflating: Videos/BYPHZXGD.mp4
#   inflating: Videos/CZORWBME.mp4
#   inflating: Videos/DGIRLTCN.mp4
#   inflating: Videos/DHMLCBME.mp4
#   inflating: Videos/YYLUPXGD.mp4
#  AKXVOXGD.mp4						    models
#  AKXVOXGD.mp4.predictions.slp				    TrainJopPgk
#  BERFBXGD.mp4						    Videos
#  BERFBXGD.mp4.predictions.slp				    Videos.zip
# 'Copy of Training_and_inference_using_Google_Drive.ipynb'

# %%
import os

def get_video_paths(folder_path):
    video_paths = []
    valid_extensions = ['.mp4', '.avi', '.mkv']  # Add more extensions if needed

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            _, extension = os.path.splitext(file)
            if extension.lower() in valid_extensions:
                video_path = os.path.join(root, file)
                video_paths.append(video_path)

    return video_paths

# Example usage
folder_path = '/content/drive/MyDrive/COCOHorseSleapPose/Videos'  # Replace with the actual folder path

video_paths = get_video_paths(folder_path)
for path in video_paths:
    print(path)
# Out:
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/AHTCDBME.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/AKPNRXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/AKXVOXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/AMVQFXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/AMZSRXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/ANGLMXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/ANMSEBME.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/APZQNXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/AQCYDXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/ARNCVXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/ASHUOMHZ.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/ATSFLXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/BERFBXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/BOEFDXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/BYPHZXGD.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/CZORWBME.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/DGIRLTCN.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/DHMLCBME.mp4
# /content/drive/MyDrive/COCOHorseSleapPose/Videos/YYLUPXGD.mp4

# %%
import cv2

def get_frame_count(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    return frame_count

# %%
for video in video_paths :
  frame_count = get_frame_count(video) - 1
  # !sleap-track $video \
    --frames 0-$frame_count \
    --tracking.tracker simple \
    -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance \
    -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-18 07:31:12.073084
# Args:
# {
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AHTCDBME.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-103',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AHTCDBME.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-18 07:31:20.025893: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:31:20.026783: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:31:20.034525: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 13.7 FPS
# Finished inference at: 2023-05-18 07:31:36.951308
# Total runtime: 24.87823987007141 secs
# Predicted frames: 104/104
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/drive/MyDrive/COCOHorseSleapPose/Videos/AHTCDBME.mp4 --frames 0-103 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AHTCDBME.mp4',
# │   'output_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AHTCDBME.mp4.predictions.slp',
# │   'total_elapsed': 24.87823987007141,
# │   'start_timestamp': '2023-05-18 07:31:12.073084',
# │   'finish_timestamp': '2023-05-18 07:31:36.951308'
# }
#
# Saved output: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AHTCDBME.mp4.predictions.slp
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-18 07:31:44.810607
# Args:
# {
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AKPNRXGD.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-93',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AKPNRXGD.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-18 07:31:54.165588: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:31:54.166213: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:31:54.171365: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺  98% ETA: 0:00:01 11.2 FPS2023-05-18 07:32:12.268458: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:32:12.269044: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 2 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:32:12.274429: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 5.2 FPS
# Finished inference at: 2023-05-18 07:32:30.718533
# Total runtime: 45.90794396400452 secs
# Predicted frames: 94/94
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/drive/MyDrive/COCOHorseSleapPose/Videos/AKPNRXGD.mp4 --frames 0-93 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AKPNRXGD.mp4',
# │   'output_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AKPNRXGD.mp4.predictions.slp',
# │   'total_elapsed': 45.90794396400452,
# │   'start_timestamp': '2023-05-18 07:31:44.810607',
# │   'finish_timestamp': '2023-05-18 07:32:30.718533'
# }
#
# Saved output: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AKPNRXGD.mp4.predictions.slp
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-18 07:32:38.679987
# Args:
# {
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AKXVOXGD.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-76',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AKXVOXGD.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-18 07:32:47.869565: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:32:47.870144: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:32:47.875735: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺  99% ETA: 0:00:01 15.2 FPS2023-05-18 07:32:59.583515: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:32:59.584463: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 1 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:32:59.594306: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 8.2 FPS
# Finished inference at: 2023-05-18 07:33:04.082709
# Total runtime: 25.40273880958557 secs
# Predicted frames: 77/77
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/drive/MyDrive/COCOHorseSleapPose/Videos/AKXVOXGD.mp4 --frames 0-76 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AKXVOXGD.mp4',
# │   'output_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AKXVOXGD.mp4.predictions.slp',
# │   'total_elapsed': 25.40273880958557,
# │   'start_timestamp': '2023-05-18 07:32:38.679987',
# │   'finish_timestamp': '2023-05-18 07:33:04.082709'
# }
#
# Saved output: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AKXVOXGD.mp4.predictions.slp
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-18 07:33:14.675051
# Args:
# {
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AMVQFXGD.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-115',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AMVQFXGD.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-18 07:33:23.807113: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:33:23.807644: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:33:23.812985: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 18.7 FPS
# Finished inference at: 2023-05-18 07:33:33.688172
# Total runtime: 19.013137102127075 secs
# Predicted frames: 116/116
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/drive/MyDrive/COCOHorseSleapPose/Videos/AMVQFXGD.mp4 --frames 0-115 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AMVQFXGD.mp4',
# │   'output_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AMVQFXGD.mp4.predictions.slp',
# │   'total_elapsed': 19.013137102127075,
# │   'start_timestamp': '2023-05-18 07:33:14.675051',
# │   'finish_timestamp': '2023-05-18 07:33:33.688172'
# }
#
# Saved output: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AMVQFXGD.mp4.predictions.slp
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-18 07:33:43.021399
# Args:
# {
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AMZSRXGD.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-59',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AMZSRXGD.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-18 07:33:49.801722: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:33:49.802283: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:33:49.807782: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 9.4 FPS
# Finished inference at: 2023-05-18 07:34:06.840108
# Total runtime: 23.81872534751892 secs
# Predicted frames: 60/60
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/drive/MyDrive/COCOHorseSleapPose/Videos/AMZSRXGD.mp4 --frames 0-59 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AMZSRXGD.mp4',
# │   'output_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/AMZSRXGD.mp4.predictions.slp',
# │   'total_elapsed': 23.81872534751892,
# │   'start_timestamp': '2023-05-18 07:33:43.021399',
# │   'finish_timestamp': '2023-05-18 07:34:06.840108'
# }
#
# Saved output: /content/drive/MyDrive/COCOHorseSleapPose/Videos/AMZSRXGD.mp4.predictions.slp
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-18 07:34:16.680480
# Args:
# {
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/ANGLMXGD.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-71',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/ANGLMXGD.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-18 07:34:23.376680: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:34:23.377246: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:34:23.382494: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 24.6 FPS
# Finished inference at: 2023-05-18 07:34:30.517332
# Total runtime: 13.836909294128418 secs
# Predicted frames: 72/72
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/drive/MyDrive/COCOHorseSleapPose/Videos/ANGLMXGD.mp4 --frames 0-71 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/ANGLMXGD.mp4',
# │   'output_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/ANGLMXGD.mp4.predictions.slp',
# │   'total_elapsed': 13.836909294128418,
# │   'start_timestamp': '2023-05-18 07:34:16.680480',
# │   'finish_timestamp': '2023-05-18 07:34:30.517332'
# }
#
# Saved output: /content/drive/MyDrive/COCOHorseSleapPose/Videos/ANGLMXGD.mp4.predictions.slp
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-18 07:34:39.254829
# Args:
# {
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/ANMSEBME.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-79',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/ANMSEBME.mp4
# ...
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-45',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/DHMLCBME.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-18 07:40:46.652352: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:40:46.652934: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:40:46.658698: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━  96% ETA: 0:00:01 29.3 FPS2023-05-18 07:40:53.811039: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:40:53.811540: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 2 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:40:53.817478: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 13.6 FPS
# Finished inference at: 2023-05-18 07:40:54.588374
# Total runtime: 16.807961225509644 secs
# Predicted frames: 46/46
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/drive/MyDrive/COCOHorseSleapPose/Videos/DHMLCBME.mp4 --frames 0-45 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/DHMLCBME.mp4',
# │   'output_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/DHMLCBME.mp4.predictions.slp',
# │   'total_elapsed': 16.807961225509644,
# │   'start_timestamp': '2023-05-18 07:40:37.780431',
# │   'finish_timestamp': '2023-05-18 07:40:54.588374'
# }
#
# Saved output: /content/drive/MyDrive/COCOHorseSleapPose/Videos/DHMLCBME.mp4.predictions.slp
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Started inference at: 2023-05-18 07:41:04.379780
# Args:
# {
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/YYLUPXGD.mp4',
# │   'models': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid'
# │   ],
# │   'frames': '0-83',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': None,
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'tracking.tracker': 'simple',
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 15098 MiB of free memory.
# Versions:
# SLEAP: 1.3.0
# TensorFlow: 2.8.4
# Numpy: 1.22.4
# Python: 3.10.11
# OS: Linux-5.15.107+-x86_64-with-glibc2.31
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/MyDrive/COCOHorseSleapPose/Videos/YYLUPXGD.mp4
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% ETA: -:--:-- ?2023-05-18 07:41:11.325795: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: -57 } dim { size: -58 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -59 } dim { size: -60 } dim { size: 1 } } }
# 2023-05-18 07:41:11.326486: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_UINT8 } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_UINT8 shape { dim { size: 4 } dim { size: 360 } dim { size: 640 } dim { size: 3 } } } inputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -2 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2299 num_cores: 2 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 47185920 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -2 } dim { size: -67 } dim { size: -68 } dim { size: 3 } } }
# 2023-05-18 07:41:11.331897: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: -112 } dim { size: -113 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -6 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14395703296 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { size: -6 } dim { size: -114 } dim { size: -115 } dim { size: 1 } } }
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 19.6 FPS
# Finished inference at: 2023-05-18 07:41:28.232188
# Total runtime: 23.85242247581482 secs
# Predicted frames: 84/84
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance/training_config.json',
# │   │   '/content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid/training_config.json'
# │   ],
# │   'predictor': 'TopDownPredictor',
# │   'sleap_version': '1.3.0',
# │   'platform': 'Linux-5.15.107+-x86_64-with-glibc2.31',
# │   'command': '/usr/local/bin/sleap-track /content/drive/MyDrive/COCOHorseSleapPose/Videos/YYLUPXGD.mp4 --frames 0-83 --tracking.tracker simple -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centered_instance -m /content/drive/MyDrive/COCOHorseSleapPose/models/230513_124413.centroid',
# │   'data_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/YYLUPXGD.mp4',
# │   'output_path': '/content/drive/MyDrive/COCOHorseSleapPose/Videos/YYLUPXGD.mp4.predictions.slp',
# │   'total_elapsed': 23.85242247581482,
# │   'start_timestamp': '2023-05-18 07:41:04.379780',
# │   'finish_timestamp': '2023-05-18 07:41:28.232188'
# }
#
# Saved output: /content/drive/MyDrive/COCOHorseSleapPose/Videos/YYLUPXGD.mp4.predictions.slp
